# %% [markdown]
# seasonal decomposition
# ---

# %% [markdown]
# ETS-Decomposition
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# Perform standard imports and load the dataset
# ---

# %%
airline = pd.read_csv(r'C:\Users\Mahnaz\Desktop\test_seasonal_decomposition\airline_passengers.csv',index_col='Month',parse_dates=True)

# %%
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
airline.dropna(inplace=True)

# %%
airline.plot();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(airline['Thousands of Passengers'], model='multiplicative')  # model='mul' also works
result.plot();

# %% [markdown]
# SMA
# ---

# %% [markdown]
# simple moving average
# ---

# %%
airline['6-month-SMA'] = airline['Thousands of Passengers'].rolling(window=6).mean()
airline['12-month-SMA'] = airline['Thousands of Passengers'].rolling(window=12).mean()

# %%
airline.head(15)
# Out:
#             Thousands of Passengers  6-month-SMA  12-month-SMA
# Month
# 1949-01-01                      112          NaN           NaN
# 1949-02-01                      118          NaN           NaN
# 1949-03-01                      132          NaN           NaN
# 1949-04-01                      129          NaN           NaN
# 1949-05-01                      121          NaN           NaN
# 1949-06-01                      135   124.500000           NaN
# 1949-07-01                      148   130.500000           NaN
# 1949-08-01                      148   135.500000           NaN
# 1949-09-01                      136   136.166667           NaN
# 1949-10-01                      119   134.500000           NaN
# 1949-11-01                      104   131.666667           NaN
# 1949-12-01                      118   128.833333    126.666667
# 1950-01-01                      115   123.333333    126.916667
# 1950-02-01                      126   119.666667    127.583333
# 1950-03-01                      141   120.500000    128.333333

# %% [markdown]
# EWMA (Exponentially Weighted Moving Average)
# ---

# %%
airline['EWMA12'] = airline['Thousands of Passengers'].ewm(span=12,adjust=False).mean()

# %%
airline[['Thousands of Passengers','EWMA12']].plot();

# %% [markdown]
# Comparing SMA to EWMA
# ---

# %%
airline[['Thousands of Passengers','EWMA12','12-month-SMA']].plot(figsize=(12,8)).autoscale(axis='x',tight=True);

# %% [markdown]
# Holt-Winters Methods
# ---

# %%
df = pd.read_csv(r'C:\Users\Mahnaz\Desktop\test_seasonal_decomposition\airline_passengers.csv',index_col='Month',parse_dates=True)

# %%
df.dropna(inplace=True)

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %% [markdown]
# Setting a DatetimeIndex Frequency
# ---

# %%
df.index.freq = 'MS'
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %%
df.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %% [markdown]
# Simple Exponential Smoothing
# ---

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

span = 12
alpha = 2/(span+1)

df['EWMA12'] = df['Thousands of Passengers'].ewm(alpha=alpha,adjust=False).mean()
df['SES12']=SimpleExpSmoothing(df['Thousands of Passengers']).fit(smoothing_level=alpha,optimized=False).fittedvalues.shift(-1)
df.head()
# Out:
#             Thousands of Passengers      EWMA12       SES12
# Month
# 1949-01-01                      112  112.000000  112.000000
# 1949-02-01                      118  112.923077  112.923077
# 1949-03-01                      132  115.857988  115.857988
# 1949-04-01                      129  117.879836  117.879836
# 1949-05-01                      121  118.359861  118.359861
